# %%
import json
import pandas as pd
import tweepy

# %% [markdown]
# ## Load data

# %%
# Load JSON data from a file
with open('tweets_final_top.json') as f:
    data1 = json.load(f)

with open('tweets_final.json') as f:
    data2 = json.load(f)

# Convert lists of dictionaries into DataFrames
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# Combine the two DataFrames
combined_df = pd.concat([df1, df2], ignore_index=True)

# Remove duplicates based on the specified columns
df = combined_df.drop_duplicates(subset=['created_at', 'username', 'Text', 'Competitor'])

# %%
# Display the DataFrame's columns
df.describe()
# Out:
#                             created_at  username  \
# count                              645       645
# unique                             564       431
# top     Wed Aug 07 10:14:10 +0000 2024  FloTrack
# freq                                 7         9
#
#                                                      Text     Competitor
# count                                                 645            645
# unique                                                565             22
# top     [🏃‍♂️] Les athlètes qualifiés en finale du 5 0...  Oscar Chelimo
# freq                                                    7             40

# %%
competitor_counts = df.groupby('Competitor').size()

print(competitor_counts)
# Out:
# Competitor
# Addisu Yihune               31
# Biniam Mehary               19
# Dawit Seare                 21
# Dominic Lokinyomo Lobalu    18
# Edwin Kurgat                27
# George Mills                33
# Graham Blanks               21
# Grant Fisher                38
# Hagos Gebrhiwet             18
# Hugo Hay                    39
# Isaac Kimeli                34
# Jacob Krop                  29
# Jakob Ingebrigtsen          36
# John Heymans                32
# Mike Foppen                 33
# Narve Gilje Nordas          29
# Oscar Chelimo               40
# Ronald Kwemoi               27
# Stewart Mcsweyn             18
# Thierry Ndikumwenayo        35
# Thomas Fafard               33
# Yann Schrub                 34
# dtype: int64

# %%
# Load hugging face token
with open('hf_token.json') as file:
    json_obj = json.load(file)
    key=json_obj["Key"]

# %% [markdown]
# ## BERT-Based Models

# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in c:\users\leaka\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: torchvision in c:\users\leaka\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: torchaudio in c:\users\leaka\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: fsspec in c:\users\leaka\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: networkx in c:\users\leaka\anaconda3\lib\site-packages (from torch) (2.5)
# Requirement already satisfied: jinja2 in c:\users\leaka\anaconda3\lib\site-packages (from torch) (2.11.3)
# Requirement already satisfied: sympy in c:\users\leaka\anaconda3\lib\site-packages (from torch) (1.8)
# Requirement already satisfied: filelock in c:\users\leaka\anaconda3\lib\site-packages (from torch) (3.0.12)
# Collecting typing-extensions>=4.8.0
#   Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: numpy<2 in c:\users\leaka\anaconda3\lib\site-packages (from torchvision) (1.22.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\leaka\anaconda3\lib\site-packages (from torchvision) (8.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\leaka\anaconda3\lib\site-packages (from jinja2->torch) (1.1.1)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\leaka\anaconda3\lib\site-packages (from networkx->torch) (5.0.6)
# Requirement already satisfied: mpmath>=0.19 in c:\users\leaka\anaconda3\lib\site-packages (from sympy->torch) (1.2.1)
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.5.0
#     Uninstalling typing-extensions-4.5.0:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
#       Successfully uninstalled typing-extensions-4.5.0
# Successfully installed typing-extensions-4.12.2

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-eb42ca6e4af3> in <module>
# ----> 1 import torch
#
# ~\anaconda3\lib\site-packages\torch\__init__.py in <module>
#      29     return sys.modules.get("torch._meta_registrations", None) is object
#      30
# ---> 31 from ._utils import _import_dotted_name, classproperty
#      32 from ._utils import _functionalize_sync as _sync
#      33 from ._utils_internal import get_file_path, prepare_multiprocessing_environment, \
#
# ~\anaconda3\lib\site-packages\torch\_utils.py in <module>
#       9 from collections import defaultdict
#      10 from typing import Any, Callable, DefaultDict, Generic, List, Optional
# ---> 11 from typing_extensions import ParamSpec
#      12
#      13 import torch
#
# ImportError: cannot import name 'ParamSpec' from 'typing_extensions' (C:\Users\leaka\anaconda3\lib\site-packages\typing_extensions.py)

# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import pipeline

# Load the pre-trained model and tokenizer
model_name = "cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# Create a pipeline for sentiment analysis
sentiment_pipeline = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# Function to get sentiment for each tweet
def get_sentiment(text):
    result = sentiment_pipeline(text)
    return result[0]['label'], result[0]['score']

# Apply the sentiment analysis to the "Text" column
df['Sentiment'], df['Confidence'] = zip(*df['Text'].apply(get_sentiment))

# Display the DataFrame with the sentiment results
print(df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-15-7b6a7b918426> in <module>
#       6 model_name = "cardiffnlp/twitter-roberta-base-sentiment"
#       7 tokenizer = AutoTokenizer.from_pretrained(model_name)
# ----> 8 model = AutoModelForSequenceClassification.from_pretrained(model_name)
#       9
#      10 # Create a pipeline for sentiment analysis
#
# ~\anaconda3\lib\site-packages\transformers\utils\import_utils.py in __getattribute__(cls, key)
#    1541         if key.startswith("_") and key != "_from_config":
#    1542             return super().__getattribute__(key)
# -> 1543         requires_backends(cls, cls._backends)
#    1544
#    1545
#
# ~\anaconda3\lib\site-packages\transformers\utils\import_utils.py in requires_backends(obj, backends)
#    1520     # Raise an error for users who might not realize that classes without "TF" are torch-only
#    1521     if "torch" in backends and "tf" not in backends and not is_torch_available() and is_tf_available():
# -> 1522         raise ImportError(PYTORCH_IMPORT_ERROR_WITH_TF.format(name))
#    1523
#    1524     # Raise the inverse error for PyTorch users trying to load TF classes
#
# ImportError:
# AutoModelForSequenceClassification requires the PyTorch library but it was not found in your environment.
# However, we were able to find a TensorFlow installation. TensorFlow classes begin
# with "TF", but are otherwise identically named to our PyTorch classes. This
# means that the TF equivalent of the class you tried to import would be "TFAutoModelForSequenceClassification".
# If you want to use TensorFlow, please use TF classes instead!
#
# If you really do want to use PyTorch please go to
# https://pytorch.org/get-started/locally/ and follow the instructions that
# match your environment.
